# %%
# !which python
# !nvidia-smi -L
# Out:
# /home/FYP/siddhant005/.conda/envs/retagnn_pyg/bin/python
# GPU 0: Tesla V100-PCIE-32GB (UUID: GPU-cdfa375c-ed7a-44a9-71a3-8be9a7573878)

# %%
# !python /home/FYP/siddhant005/fyp/src/main.py -d ml-100k --uniform --bs 256
# Out:
# INFO:	main:	Namespace(n_degree=20, n_head=2, n_layer=2, drop_out=0.1, reg=0.1, node_dim=32, time_dim=32, agg_method='attn', attn_mode='map', uniform=True, new_node=False, time='disentangle', disencomponents=10, data='ml-100k', samplerate=1.0, popnegsample=False, timepopnegsample=False, negsampleeval=-1, bs=256, n_epoch=500, lr=0.0001, prefix='ml100k', gpu=0, seed=42, l2=0.0001, ckpt_epoch=10)
# INFO:	TGSRec:	Aggregation uses attention model
# INFO:	TGSRec:	Using disentangle time encoding
# INFO:	main:	Commencing training for 500 epochs
# INFO:	trainer:	Commencing training for epoch # 1
# INFO:	trainer:	Epoch 1, batch 1/79
# INFO:	trainer:	Epoch 1, batch 2/79
# INFO:	trainer:	Epoch 1, batch 3/79
# INFO:	trainer:	Epoch 1, batch 4/79
# INFO:	trainer:	Epoch 1, batch 5/79
# INFO:	trainer:	Epoch 1, batch 6/79
# INFO:	trainer:	Epoch 1, batch 7/79
# INFO:	trainer:	Epoch 1, batch 8/79
# INFO:	trainer:	Epoch 1, batch 9/79
# INFO:	trainer:	Epoch 1, batch 10/79
# ...
