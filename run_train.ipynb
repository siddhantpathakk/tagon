# %%
# !nvidia-smi -L
# !which python
# Out:
# GPU 0: Tesla V100-PCIE-32GB (UUID: GPU-cdfa375c-ed7a-44a9-71a3-8be9a7573878)
# /home/FYP/siddhant005/.conda/envs/retagnn_pyg/bin/python

# %%
# !python /home/FYP/siddhant005/fyp/src/main.py -d amazon --uniform --bs 128 --n_epoch 3 --negsampleeval 1000
# Out:
# [17/Mar/2024 07:42:58] :: INFO :: [root.set_up_logger:80] :: Logging to ./log/2024-03-17-07-42-58.log
# [17/Mar/2024 07:42:58] :: INFO :: [root.<module>:14] :: Namespace(n_degree=30, n_head=2, n_layer=2, drop_out=0.3, reg=0.3, node_dim=32, time_dim=32, agg_method='attn', attn_mode='map', uniform=True, new_node=False, time='disentangle', disencomponents=10, data='amazon', train_test_val='80-10-10', samplerate=1.0, popnegsample=False, timepopnegsample=False, negsampleeval=1000, bs=128, n_epoch=1, lr=0.001, prefix='ml100k', gpu=0, seed=42, l2=0.01, ckpt_epoch=10, pretrain=None)
# [17/Mar/2024 07:42:58] :: INFO :: [utils.data_utils.split_data:43] :: Train split: 80%, Val split: 10%, Test split: 10%
# [17/Mar/2024 07:42:58] :: INFO :: [utils.data_utils.split_data:132] :: #Interactions in VALID: 2183
# [17/Mar/2024 07:42:58] :: INFO :: [utils.data_utils.split_data:133] :: #Interactions in TEST: 984
# ...
